# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmaymaloo/EdgeDetection/blob/master/Edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#if you are using it in spyder or anaconda use !pip install cv2 (Note: prefered to run over here only)
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
font = cv2.FONT_HERSHEY_COMPLEX
from google.colab.patches import cv2_imshow
from PIL import Image

# %%
img =cv2.VideoCapture(0)

# %%
#import the image here and copy its filename
#Change the path name 
path_name="/content/WhatsApp Image 2019-11-02 at 7.42.43 PM.jpeg"
img2 = cv2.imread(path_name)
img = cv2.imread(path_name, cv2.IMREAD_GRAYSCALE)
_, threshold = cv2.threshold(img, 250, 255, cv2.THRESH_BINARY)
contours,_ = cv2.findContours(threshold, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=391x288 at 0x7FCBE0F260F0>

# %%
#Drawing contours
for cnt in contours:
    Len=0.01*cv2.arcLength(cnt, True)
    approx = cv2.approxPolyDP(cnt, Len, True)
    cv2.drawContours(img, [approx], 0, (0), 1)
    x = approx.ravel()[0]
    y = approx.ravel()[1]

# %%
#For cropping, saving and giving boundary limits to currency
idx = 0
for c in contours:
  x, y, w, h = cv2.boundingRect(c)
  if (w > 80 and h > 20) and w is not 0 and y is not 0:
    idx += 1
    new_img = img2[y:y+h, x:x+w]
    cv2_imshow(new_img)
    #if not using colab use cv2.imshow insted of cv2_imshow
    cv2.imwrite(str(idx)+'.png', new_img)
    #download it to your PC
# Out:
# <PIL.Image.Image image mode=RGB size=184x87 at 0x7FCBE0E9D8D0>
# <PIL.Image.Image image mode=RGB size=184x87 at 0x7FCBE0E9D828>
# <PIL.Image.Image image mode=RGB size=184x89 at 0x7FCBE0E9D8D0>
# <PIL.Image.Image image mode=RGB size=184x88 at 0x7FCBE0E9D828>
# <PIL.Image.Image image mode=RGB size=185x87 at 0x7FCBE0E9D8D0>
